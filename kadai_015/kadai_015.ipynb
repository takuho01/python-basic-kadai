# %%
# kadai 015

# class : human (name , age, )
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(self.name, self.age)
    

Human1 = Human("山田太郎", 20)
Human1.printinfo()
